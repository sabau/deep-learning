# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /home/sabau/anaconda3/envs/aind/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

t = 1e-5
word_counter = Counter(int_words)
total = len(int_words)
f = {word: nr/total for word, nr in word_counter.items()}
drop_prob = {word: 1 - np.sqrt(t/f[word]) for word in word_counter}
train_words = [word for word in int_words if drop_prob[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    rand = np.random.randint(0, window_size) + 1
    start = max(0, idx-rand)
    end = min(len(words), idx+rand)
    return list(set(words[start:idx] + words[idx+1:end+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 150 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding),stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed, 
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/sabau/anaconda3/envs/aind/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-0edb403d10d5>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5883 0.1540 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5398 0.1490 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4896 0.1518 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5619 0.1503 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4598 0.1497 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4857 0.1494 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4757 0.1501 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4780 0.1498 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4368 0.1498 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3810 0.1504 sec/batch
# Nearest to state: dern, diviners, staff, geometry, tomas, crust, kitty, uploads,
# Nearest to had: dalit, ug, dicky, numerically, rumba, inverness, macrophages, so,
# Nearest to eight: intersection, salamander, afterburner, disliking, millenarian, microtubule, vet, spongebob,
# Nearest to no: transpersonal, accountable, remediation, legitimate, lakeside, strangle, msson, scrupulously,
# Nearest to at: suspension, commander, configuration, campesinos, monteiro, artefact, leningrad, faunal,
# Nearest to with: wickham, socialized, walla, anarchism, minden, chemin, violently, canine,
# Nearest to may: ghulam, fenced, adt, circa, binswanger, sintered, liebster, bibliotheke,
# Nearest to four: kensington, pornography, volkswagen, encyclopedia, methodus, lenr, authorised, malware,
# Nearest to shown: dichromate, satisfiable, burkean, pearly, dowleh, honor, lucio, contractile,
# Nearest to scale: matra, jhana, finalised, syrups, kline, politiques, popped, confirm,
# Nearest to engineering: clutch, healey, catacombs, context, hyaena, sunburn, monro, sadi,
# Nearest to cost: harsh, semivowel, staff, synthesis, centimes, humanitarian, invoking, sncf,
# Nearest to units: fayyum, harappa, paypal, jingles, snow, pruitt, kto, saucer,
# Nearest to powers: talents, disbelieved, zagreb, mahal, generalization, commited, bose, breitman,
# Nearest to except: written, hoffman, lps, underemployed, cedes, sigurd, giorgio, iudaea,
# Nearest to mean: fossilized, albertus, subsystem, passed, entertains, cofinality, constituent, taxation,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4379 0.1534 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3418 0.1505 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3192 0.1494 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2438 0.1495 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1863 0.1496 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1391 0.1501 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1047 0.1502 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0573 0.1537 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9895 0.1604 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9650 0.1484 sec/batch
# Nearest to state: staff, is, dern, geometry, rejected, compilers, such, crust,
# Nearest to had: so, father, part, experience, suffix, numerically, protest, celtic,
# Nearest to eight: intersection, bibliography, microtubule, posed, asia, conventional, millenarian, augsburg,
# Nearest to no: legitimate, accountable, supported, transpersonal, reliable, msson, rare, graduation,
# Nearest to at: configuration, commander, drawn, suspension, caymanians, idolized, interdependent, distinctive,
# Nearest to with: is, against, second, violently, chose, anarchism, wickham, clav,
# Nearest to may: ghulam, close, privatization, mount, freedom, english, cindy, partitioned,
# Nearest to four: tv, volkswagen, pornography, kensington, noting, encyclopedia, neil, organizing,
# Nearest to shown: dichromate, crystallography, processed, honor, globalization, islamic, western, industrial,
# Nearest to scale: matra, jhana, popped, confirm, compilation, syrups, third, september,
# Nearest to engineering: context, clutch, robert, catacombs, during, healey, thirds, traditionally,
# Nearest to cost: staff, harsh, synthesis, humanitarian, retrieval, enough, philosophic, opposition,
# Nearest to units: harappa, concert, tort, snow, jingles, paypal, move, characters,
# Nearest to powers: talents, dollars, zagreb, referred, conducted, houses, commited, miraculously,
# Nearest to except: written, lps, nine, underemployed, hoffman, divergent, food, ending,
# Nearest to mean: fossilized, passed, requirements, albertus, agreements, subsystem, digit, digges,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9327 0.1501 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9008 0.1477 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8709 0.1488 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8382 0.1483 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7945 0.1478 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8054 0.1488 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7744 0.1486 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7865 0.1483 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7717 0.1494 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7665 0.1489 sec/batch
# Nearest to state: staff, geometry, kitty, dern, rejected, crust, compilers, antisocial,
# Nearest to had: passenger, rumba, protest, dalit, numerically, father, ug, celtic,
# Nearest to eight: bibliography, intersection, fiscal, augsburg, salamander, five, christoph, statesman,
# Nearest to no: accountable, legitimate, transpersonal, supported, wait, terminology, remediation, exceptions,
# Nearest to at: configuration, commander, suspension, drawn, faunal, campesinos, interdependent, distinctive,
# Nearest to with: chose, is, socialized, wickham, risen, violently, anarchism, against,
# Nearest to may: ghulam, emotions, privatization, freedom, belgian, advocates, fenced, close,
# Nearest to four: tv, neil, volkswagen, kensington, noting, extraordinary, organizing, coaches,
# Nearest to shown: dichromate, honor, processed, crystallography, islamic, globalization, revolutionaries, pickles,
# Nearest to scale: matra, confirm, finalised, jhana, compilation, popped, syrups, prohibitions,
# Nearest to engineering: context, clutch, thirds, healey, researcher, catacombs, sunburn, groupings,
# Nearest to cost: harsh, staff, synthesis, philosophic, retrieval, invoking, humanitarian, opposition,
# Nearest to units: harappa, snow, move, tort, concert, races, initiative, ensure,
# Nearest to powers: dollars, talents, houses, generalization, conducted, referred, legislation, fdl,
# Nearest to except: written, hoffman, lps, underemployed, giorgio, rudy, divergent, gay,
# Nearest to mean: fossilized, passed, requirements, taxation, agreements, subsystem, albertus, constituent,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7613 0.1517 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7245 0.1492 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7087 0.1489 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7100 0.1484 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7082 0.1502 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6749 0.1505 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7200 0.1496 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7108 0.1490 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6629 0.1492 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6701 0.1479 sec/batch
# Nearest to state: staff, kitty, rejected, dern, antisocial, chelmsford, geometry, compilers,
# Nearest to had: dalit, rumba, father, passenger, dicky, depot, rap, kv,
# Nearest to eight: five, statesman, politician, bibliography, seven, augsburg, inventor, salamander,
# Nearest to no: accountable, transpersonal, legitimate, lle, wait, remediation, scrupulously, laurentian,
# Nearest to at: configuration, faunal, campesinos, commander, drawn, leningrad, suspension, millikan,
# Nearest to with: wickham, socialized, chose, risen, anarchism, bathroom, violently, walla,
# Nearest to may: ghulam, emotions, privatization, belgian, advocates, fenced, bx, mount,
# Nearest to four: volkswagen, neil, kensington, coaches, tv, amos, one, wilhelm,
# Nearest to shown: dichromate, crystallography, honor, processed, islamic, globalization, rounds, paradigms,
# Nearest to scale: matra, finalised, confirm, jhana, kline, syrups, prohibitions, compilation,
# Nearest to engineering: context, clutch, healey, sunburn, reconquista, thirds, shakti, monro,
# Nearest to cost: harsh, staff, synthesis, invoking, shortages, philosophic, decrypt, louth,
# Nearest to units: harappa, snow, move, races, tort, elevator, counting, uh,
# Nearest to powers: dollars, talents, houses, conducted, generalization, miraculously, legislation, fdl,
# Nearest to except: hoffman, written, lps, giorgio, rudy, underemployed, cedes, regulus,
# Nearest to mean: fossilized, taxation, requirements, subsystem, passed, albertus, constituent, agreements,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6476 0.1499 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6469 0.1484 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6208 0.1498 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6372 0.1483 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6425 0.1486 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6269 0.1480 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5735 0.1121 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5785 0.1481 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5319 0.1475 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4961 0.1482 sec/batch
# Nearest to state: kitty, staff, dern, chelmsford, rejected, waning, antisocial, musicbrainz,
# Nearest to had: dalit, father, rumba, depot, gasp, protest, withdraw, kv,
# Nearest to eight: statesman, five, inventor, politician, d, seven, henri, six,
# Nearest to no: accountable, transpersonal, legitimate, lle, scrupulously, exceptions, typed, remediation,
# Nearest to at: campesinos, faunal, configuration, drawn, suspension, commander, artefact, leningrad,
# Nearest to with: wickham, socialized, violently, anarchism, bathroom, walla, chose, representations,
# Nearest to may: emotions, ghulam, fenced, privatization, bx, advocates, sintered, voicing,
# Nearest to four: neil, one, volkswagen, wilhelm, amos, physicist, tv, coaches,
# Nearest to shown: dichromate, crystallography, processed, paradigms, contractile, globalization, bloated, enable,
# Nearest to scale: matra, finalised, obstruction, confirm, jhana, syrups, prohibitions, politiques,
# Nearest to engineering: clutch, healey, context, sunburn, catacombs, reconquista, monro, hyaena,
# Nearest to cost: harsh, staff, shortages, semivowel, bonded, louth, decrypt, invoking,
# Nearest to units: harappa, snow, surface, move, races, counting, uh, elevator,
# Nearest to powers: talents, dollars, conducted, houses, politically, legislation, fdl, marcos,
# Nearest to except: hoffman, written, giorgio, lps, rudy, cedes, regulus, is,
# Nearest to mean: fossilized, requirements, subsystem, albertus, sterility, taxation, proportion, flash,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5082 0.1498 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5100 0.1482 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4824 0.1485 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5473 0.1480 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5072 0.1486 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4975 0.1486 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4706 0.1479 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4169 0.1482 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4443 0.1483 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4671 0.1478 sec/batch
# Nearest to state: staff, kitty, dern, chelmsford, rejected, musicbrainz, democratic, coup,
# Nearest to had: dalit, father, protest, rumba, gasp, withdraw, escaped, depot,
# Nearest to eight: statesman, five, inventor, henri, salamander, politician, remarried, seven,
# Nearest to no: accountable, transpersonal, lle, legitimate, exceptions, typed, terminology, scrupulously,
# Nearest to at: campesinos, configuration, drawn, suspension, faunal, idolized, racehorse, accelerating,
# Nearest to with: wickham, socialized, walla, bathroom, violently, anarchism, representations, drowsiness,
# Nearest to may: emotions, fenced, ghulam, privatization, advocates, sintered, voicing, claim,
# Nearest to four: neil, amos, one, wilhelm, hatchet, hispanic, two, michel,
# Nearest to shown: dichromate, crystallography, processed, paradigms, contractile, enable, satisfiable, coronations,
# Nearest to scale: matra, finalised, obstruction, confirm, syrups, jhana, citigroup, prohibitions,
# Nearest to engineering: context, clutch, healey, sunburn, catacombs, monro, shakti, hyaena,
# Nearest to cost: harsh, bonded, staff, semivowel, shortages, louth, decrypt, synthesis,
# Nearest to units: snow, harappa, surface, counting, move, races, saucer, construction,
# Nearest to powers: talents, dollars, conducted, legislation, politically, houses, marcos, miraculously,
# Nearest to except: hoffman, written, lps, regulus, giorgio, is, blackmailed, cedes,
# Nearest to mean: fossilized, requirements, subsystem, sterility, albertus, data, abstracted, imparts,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4523 0.1506 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4558 0.1484 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4262 0.1483 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4115 0.1479 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3956 0.1480 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4589 0.1485 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3811 0.1479 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4021 0.1490 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4275 0.1483 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3840 0.1482 sec/batch
# Nearest to state: kitty, staff, rejected, antisocial, democratic, chelmsford, uploads, dern,
# Nearest to had: dalit, father, gasp, rumba, protest, withdraw, was, escaped,
# Nearest to eight: statesman, five, inventor, seven, politician, six, henri, one,
# Nearest to no: accountable, legitimate, transpersonal, lle, typed, terminology, religionists, wait,
# Nearest to at: campesinos, configuration, faunal, drawn, millikan, suspension, trailer, racehorse,
# Nearest to with: wickham, socialized, drowsiness, representations, walla, bathroom, violently, is,
# Nearest to may: emotions, fenced, claim, advocates, tuple, furthermore, privatization, sintered,
# Nearest to four: one, neil, two, wilhelm, five, hatchet, amos, seven,
# Nearest to shown: dichromate, crystallography, processed, contractile, pearly, burkean, polluting, paradigms,
# Nearest to scale: matra, finalised, obstruction, syrups, jhana, intersect, cracks, confirm,
# Nearest to engineering: sunburn, healey, context, clutch, groupings, heap, monro, catacombs,
# Nearest to cost: harsh, shortages, bonded, staff, semivowel, decrypt, enough, pursue,
# Nearest to units: snow, harappa, surface, counting, races, move, pruitt, saucer,
# Nearest to powers: politically, legislation, dollars, talents, houses, conducted, hopwood, leaders,
# Nearest to except: hoffman, regulus, written, is, lps, smallness, giorgio, shear,
# Nearest to mean: fossilized, subsystem, requirements, sterility, albertus, abstracted, skepticism, proportion,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3906 0.1501 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4305 0.1477 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3558 0.1489 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3467 0.1479 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4041 0.1483 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3792 0.1482 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4059 0.1483 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3723 0.1483 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3457 0.1482 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3516 0.1483 sec/batch
# Nearest to state: rejected, kitty, democratic, staff, governments, roundheads, chelmsford, exercised,
# Nearest to had: dalit, gasp, rumba, father, withdraw, protest, was, demonstrations,
# Nearest to eight: five, seven, statesman, six, inventor, one, two, millenarian,
# Nearest to no: accountable, scrupulously, lle, typed, legitimate, religionists, wait, transpersonal,
# Nearest to at: faunal, campesinos, exerting, millikan, racehorse, drawn, arsenals, receipts,
# Nearest to with: wickham, socialized, walla, bathroom, drowsiness, violently, spent, chose,
# Nearest to may: claim, fenced, furthermore, emotions, advocates, sintered, privatization, conduct,
# Nearest to four: one, two, five, seven, wilhelm, hispanic, hatchet, csi,
# Nearest to shown: dichromate, crystallography, burkean, pearly, processed, conjunctive, hailstones, polluting,
# Nearest to scale: matra, finalised, syrups, cracks, jhana, intersect, obstruction, incurs,
# Nearest to engineering: healey, sunburn, heap, context, sadi, networking, clutch, kolmogorov,
# Nearest to cost: shortages, harsh, staff, bonded, enough, semivowel, decrypt, designed,
# Nearest to units: snow, harappa, races, move, surface, counting, construction, saucer,
# Nearest to powers: legislation, politically, conducted, leaders, dollars, houses, advisers, deputies,
# Nearest to except: hoffman, regulus, written, smallness, giorgio, is, lps, iudaea,
# Nearest to mean: fossilized, subsystem, sterility, requirements, albertus, skepticism, abstracted, entertains,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3629 0.1518 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2735 0.1496 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3875 0.1485 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4051 0.1475 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3969 0.1480 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2930 0.1486 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3253 0.1468 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3575 0.1484 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2363 0.1484 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2896 0.1479 sec/batch
# Nearest to state: democratic, rejected, staff, kitty, chelmsford, roundheads, exercised, governments,
# Nearest to had: dalit, gasp, father, rumba, withdraw, was, so, protest,
# Nearest to eight: five, seven, statesman, one, two, six, nine, henri,
# Nearest to no: accountable, religionists, scrupulously, typed, wait, lle, heath, transpersonal,
# Nearest to at: campesinos, faunal, exerting, millikan, racehorse, suspension, arsenals, idolized,
# Nearest to with: wickham, socialized, bathroom, walla, spent, relic, risen, colophon,
# Nearest to may: fenced, claim, privatization, partitioned, furthermore, suki, conduct, shampoo,
# Nearest to four: one, two, five, seven, zero, six, eight, three,
# Nearest to shown: dichromate, crystallography, burkean, pearly, hailstones, conjunctive, pickles, satisfiable,
# Nearest to scale: matra, finalised, syrups, temperatures, cracks, incurs, jhana, intersect,
# Nearest to engineering: healey, heap, networking, sunburn, sadi, cryptographic, rfcs, clutch,
# Nearest to cost: shortages, staff, harsh, bonded, semivowel, decrypt, designed, enough,
# Nearest to units: snow, harappa, saucer, races, counting, pruitt, surface, diluted,
# Nearest to powers: legislation, politically, conducted, leaders, advisers, deputies, breitman, dollars,
# Nearest to except: regulus, written, hoffman, giorgio, is, iudaea, dynasts, shear,
# Nearest to mean: fossilized, sterility, subsystem, skepticism, entertains, albertus, abstracted, requirements,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3080 0.1500 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3244 0.1484 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3574 0.0742 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2935 0.1484 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2673 0.1490 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2321 0.1483 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2482 0.1477 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2470 0.1483 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2468 0.1479 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2092 0.1487 sec/batch
# Nearest to state: democratic, staff, chelmsford, kitty, musicbrainz, lites, geographically, ayutthaya,
# Nearest to had: gasp, so, dalit, protest, rumba, was, father, withdraw,
# Nearest to eight: five, two, seven, one, statesman, six, nine, inventor,
# Nearest to no: accountable, religionists, scrupulously, wait, transpersonal, typed, lle, heath,
# Nearest to at: faunal, racehorse, campesinos, exerting, idolized, millikan, trailer, suspension,
# Nearest to with: wickham, socialized, walla, bathroom, tgv, relic, violently, colophon,
# Nearest to may: fenced, shampoo, privatization, wahhabis, claim, partitioned, suki, derivational,
# Nearest to four: two, one, five, seven, six, three, hatchet, eight,
# Nearest to shown: dichromate, crystallography, burkean, pickles, conjunctive, hailstones, pearly, rewarming,
# Nearest to scale: matra, finalised, syrups, incurs, cracks, jhana, temperatures, overall,
# Nearest to engineering: healey, networking, dwindle, heap, sunburn, monopolies, rfcs, abms,
# Nearest to cost: shortages, staff, designed, harsh, equipment, bonded, decrypt, semivowel,
# Nearest to units: races, snow, resumption, counting, pruitt, harappa, saucer, diluted,
# Nearest to powers: legislation, politically, advisers, deputies, conducted, leaders, breitman, congreso,
# Nearest to except: written, is, regulus, giorgio, iudaea, dynasts, blackmailed, tre,
# Nearest to mean: sterility, fossilized, subsystem, albertus, skepticism, entertains, abstracted, imparts,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2498 0.1513 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2376 0.1481 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2529 0.1489 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1865 0.1478 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1993 0.1484 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2025 0.1481 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.2072 0.1478 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1842 0.1478 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2015 0.1476 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1996 0.1480 sec/batch
# Nearest to state: democratic, governmental, kitty, musicbrainz, exercised, enterprises, staff, ayutthaya,
# Nearest to had: so, gasp, protest, dalit, withdraw, rumba, was, father,
# Nearest to eight: five, seven, two, six, one, statesman, henri, nine,
# Nearest to no: accountable, religionists, scrupulously, wait, typed, lle, transpersonal, heath,
# Nearest to at: exerting, faunal, campesinos, intruder, idolized, arsenals, suspension, afrobeat,
# Nearest to with: wickham, socialized, drowsiness, relic, tgv, walla, risen, nonpolar,
# Nearest to may: wahhabis, fenced, shampoo, sintered, claim, tuple, furthermore, milkshake,
# Nearest to four: two, five, one, seven, three, six, zero, hatchet,
# Nearest to shown: crystallography, dichromate, burkean, pickles, conjunctive, pearly, rewarming, parsecs,
# Nearest to scale: matra, finalised, cracks, syrups, incurs, jhana, turboprops, intersect,
# Nearest to engineering: networking, healey, monopolies, dwindle, heap, rfcs, sadi, cryptographic,
# Nearest to cost: shortages, staff, designed, harsh, progesterone, enough, equipment, decrypt,
# Nearest to units: resumption, races, counting, harappa, pruitt, snow, saucer, density,
# Nearest to powers: politically, legislation, advisers, deputies, congreso, breitman, houses, crematoria,
# Nearest to except: written, is, regulus, tre, shear, sandwiches, giorgio, blackmailed,
# Nearest to mean: fossilized, subsystem, sterility, entertains, albertus, skepticism, imparts, abstracted,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2026 0.1494 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2296 0.1476 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2084 0.1487 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1549 0.1475 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1883 0.1481 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1902 0.1481 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2396 0.1481 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1687 0.1476 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1453 0.1484 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2180 0.1483 sec/batch
# Nearest to state: kitty, rejected, exercised, democratic, lites, ayutthaya, heaps, governmental,
# Nearest to had: so, was, rumba, protest, dalit, gasp, withdraw, balloting,
# Nearest to eight: five, seven, one, six, two, nine, statesman, three,
# Nearest to no: accountable, religionists, scrupulously, typed, fraenkel, wait, lopster, tasker,
# Nearest to at: faunal, intruder, m, exerting, campesinos, idolized, receipts, demobilization,
# Nearest to with: wickham, socialized, tgv, risen, spent, nonpolar, drowsiness, relic,
# Nearest to may: claim, wahhabis, fenced, partitioned, shampoo, furthermore, milkshake, sintered,
# Nearest to four: five, one, two, seven, three, six, eight, zero,
# Nearest to shown: crystallography, dichromate, burkean, pickles, pearly, hailstones, bold, mev,
# Nearest to scale: matra, cracks, syrups, finalised, jhana, incurs, temperatures, turboprops,
# Nearest to engineering: networking, healey, monopolies, technology, rfcs, dwindle, sadi, heap,
# Nearest to cost: shortages, staff, harsh, designed, enough, decrypt, investment, progesterone,
# Nearest to units: resumption, races, pruitt, counting, saucer, density, harappa, bundeswehr,
# Nearest to powers: legislation, politically, deputies, advisers, parliamentary, congreso, breitman, crematoria,
# Nearest to except: written, is, regulus, tre, dynasts, giorgio, iudaea, smallness,
# Nearest to mean: fossilized, entertains, sterility, albertus, skepticism, subsystem, imparts, digges,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2345 0.1502 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1830 0.1482 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1914 0.1483 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2162 0.1477 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1490 0.1482 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1548 0.1465 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1880 0.1477 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1134 0.1482 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2284 0.1483 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2278 0.1467 sec/batch
# Nearest to state: rejected, exercised, kitty, democratic, governmental, legislative, musicbrainz, lites,
# Nearest to had: was, dalit, gasp, rumba, protest, so, withdraw, father,
# Nearest to eight: five, one, two, seven, nine, three, six, four,
# Nearest to no: accountable, religionists, scrupulously, heath, lopster, tasker, wait, typed,
# Nearest to at: exerting, faunal, idolized, demobilization, trapezohedron, millikan, intruder, receipts,
# Nearest to with: wickham, socialized, spent, tgv, walla, meets, macdonald, horseman,
# Nearest to may: claim, partitioned, conduct, wahhabis, jurisdiction, suki, furthermore, owners,
# Nearest to four: one, five, two, seven, three, eight, zero, six,
# Nearest to shown: burkean, crystallography, dichromate, pickles, pearly, hailstones, satisfiable, majesties,
# Nearest to scale: matra, finalised, cracks, incurs, syrups, jhana, turboprops, overall,
# Nearest to engineering: networking, rfcs, healey, technology, heap, monopolies, sadi, borja,
# Nearest to cost: shortages, staff, harsh, enough, progesterone, designed, decrypt, investment,
# Nearest to units: resumption, races, pruitt, saucer, bundeswehr, harappa, counting, density,
# Nearest to powers: legislation, politically, advisers, deputies, houses, crematoria, fdl, congreso,
# Nearest to except: written, regulus, is, sprout, tre, giorgio, shear, iudaea,
# Nearest to mean: fossilized, sterility, entertains, subsystem, albertus, skepticism, imparts, digges,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2363 0.1491 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1688 0.1476 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1856 0.1464 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1650 0.1462 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0689 0.1475 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1495 0.1484 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1599 0.1473 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1807 0.1476 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2236 0.0372 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1417 0.1484 sec/batch
# Nearest to state: kitty, democratic, lites, rejected, exercised, legislative, governmental, missouri,
# Nearest to had: gasp, was, rumba, so, protest, dalit, withdraw, accidentally,
# Nearest to eight: five, two, one, seven, nine, six, three, four,
# Nearest to no: accountable, scrupulously, religionists, heath, lopster, wait, tasker, strung,
# Nearest to at: exerting, faunal, idolized, intruder, scenarios, demobilization, trapezohedron, m,
# Nearest to with: wickham, socialized, tgv, misunderstood, spent, nonpolar, plagiarism, bathroom,
# Nearest to may: shampoo, wahhabis, suki, tco, partitioned, belgian, craig, conduct,
# Nearest to four: five, two, one, seven, three, zero, eight, six,
# Nearest to shown: burkean, crystallography, dichromate, pickles, hailstones, pearly, mcconnell, parsecs,
# Nearest to scale: matra, incurs, cracks, jhana, finalised, syrups, notated, obj,
# Nearest to engineering: technology, rfcs, healey, monopolies, networking, dwindle, borja, heap,
# Nearest to cost: shortages, staff, enough, progesterone, designed, harsh, decrypt, economics,
# Nearest to units: resumption, races, counting, pruitt, density, intersection, bundeswehr, saucer,
# Nearest to powers: legislation, deputies, politically, advisers, congreso, fdl, crematoria, houses,
# Nearest to except: written, is, regulus, shear, tre, sprout, giorgio, schwa,
# Nearest to mean: fossilized, sterility, subsystem, entertains, albertus, imparts, abstracted, skepticism,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1162 0.1562 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0993 0.1533 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1214 0.1533 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.1168 0.1587 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1204 0.1658 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0718 0.1502 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1423 0.1509 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0987 0.1509 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1541 0.1495 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0677 0.1494 sec/batch
# Nearest to state: lites, kitty, democratic, legislative, is, immigrant, ayutthaya, geographically,
# Nearest to had: was, dalit, so, gasp, withdraw, protest, lacked, rumba,
# Nearest to eight: five, two, one, seven, nine, six, four, three,
# Nearest to no: accountable, religionists, heath, lopster, wait, scrupulously, castletown, cosmides,
# Nearest to at: exerting, faunal, scenarios, idolized, intruder, m, receipts, trapezohedron,
# Nearest to with: wickham, socialized, second, meets, tgv, hor, walla, nonpolar,
# Nearest to may: shampoo, wahhabis, adt, conduct, claim, partitioned, owners, suki,
# Nearest to four: five, two, one, three, seven, zero, eight, six,
# Nearest to shown: burkean, crystallography, dichromate, pickles, hailstones, american, contractile, majesties,
# Nearest to scale: matra, incurs, cracks, finalised, jhana, syrups, obj, and,
# Nearest to engineering: networking, technology, rfcs, monopolies, disciplines, cryptographic, healey, radioactivity,
# Nearest to cost: shortages, staff, enough, progesterone, plans, designed, decrypt, economics,
# Nearest to units: resumption, races, counting, pruitt, density, bundeswehr, arcseconds, saucer,
# Nearest to powers: politically, deputies, legislation, advisers, fdl, congreso, crematoria, houses,
# Nearest to except: written, is, tre, shear, regulus, realschule, sprout, wolff,
# Nearest to mean: fossilized, entertains, albertus, subsystem, sterility, imparts, abstracted, digges,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0581 0.1535 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0708 0.1498 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0568 0.1487 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.1062 0.1496 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0911 0.1502 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0793 0.1506 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.1036 0.1498 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1513 0.1496 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0621 0.1502 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0708 0.1610 sec/batch
# Nearest to state: kitty, lites, is, rejected, heaps, missouri, legislative, democratic,
# Nearest to had: was, dalit, rumba, so, lacked, gasp, protest, withdraw,
# Nearest to eight: five, one, two, six, seven, nine, three, four,
# Nearest to no: accountable, religionists, lopster, wait, scrupulously, strung, heath, tasker,
# Nearest to at: faunal, scenarios, exerting, peoria, trapezohedron, idolized, afl, millikan,
# Nearest to with: wickham, socialized, nonpolar, second, meets, tgv, spent, hor,
# Nearest to may: shampoo, wahhabis, conduct, claim, adt, suki, tco, partitioned,
# Nearest to four: five, two, one, three, seven, six, zero, eight,
# Nearest to shown: burkean, crystallography, dichromate, contractile, pickles, mev, satisfiable, warped,
# Nearest to scale: matra, incurs, cracks, jhana, finalised, obj, syrups, and,
# Nearest to engineering: disciplines, monopolies, technology, psychology, engineers, rfcs, engineer, radioactivity,
# Nearest to cost: shortages, enough, staff, decrypt, progesterone, economics, designed, tradeoff,
# Nearest to units: resumption, races, density, islander, counting, pruitt, arcseconds, bundeswehr,
# Nearest to powers: deputies, politically, legislation, congreso, parliamentary, advisers, crematoria, fdl,
# Nearest to except: written, is, regulus, tre, realschule, shear, wolff, sprout,
# Nearest to mean: fossilized, entertains, albertus, sterility, subsystem, digges, imparts, skepticism,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0804 0.1747 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1090 0.1697 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1149 0.1526 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0917 0.1499 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0885 0.1512 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0660 0.1510 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0910 0.1502 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0739 0.1504 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1222 0.1507 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0936 0.1506 sec/batch
# Nearest to state: kitty, lites, rejected, is, heaps, legislative, overseen, missouri,
# Nearest to had: was, dalit, ruffians, lacked, so, withdraw, he, asherah,
# Nearest to eight: five, one, two, seven, nine, six, four, three,
# Nearest to no: accountable, lopster, religionists, wait, fraenkel, tasker, waring, xxiii,
# Nearest to at: exerting, faunal, peoria, intruder, demobilization, idolized, polybius, receipts,
# Nearest to with: socialized, wickham, second, spent, hor, its, tgv, meets,
# Nearest to may: conduct, claim, wahhabis, jurisdiction, shampoo, adt, suki, owners,
# Nearest to four: five, one, two, three, seven, zero, six, eight,
# Nearest to shown: burkean, crystallography, dichromate, satisfiable, majesties, hailstones, pickles, ket,
# Nearest to scale: matra, incurs, cracks, finalised, jhana, obj, landscapes, syrups,
# Nearest to engineering: psychology, disciplines, technology, monopolies, engineer, engineers, rfcs, sadi,
# Nearest to cost: enough, shortages, staff, economics, progesterone, decrypt, plans, harsh,
# Nearest to units: resumption, races, density, islander, pruitt, arcseconds, counting, si,
# Nearest to powers: legislation, deputies, politically, congreso, parliamentary, advisers, crematoria, fdl,
# Nearest to except: written, is, regulus, tre, schwa, wolff, realschule, reprieve,
# Nearest to mean: fossilized, entertains, albertus, digges, sterility, imparts, subsystem, skepticism,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0937 0.1519 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0279 0.1502 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0580 0.1497 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0980 0.1512 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1302 0.1510 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1597 0.1505 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1538 0.1496 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0786 0.1496 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0331 0.1490 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0779 0.1498 sec/batch
# Nearest to state: kitty, is, lites, rejected, missouri, legislative, heaps, overseen,
# Nearest to had: was, dalit, lacked, ruffians, so, rumba, gasp, successfully,
# Nearest to eight: five, two, one, three, nine, seven, four, six,
# Nearest to no: accountable, lopster, wait, religionists, waring, tasker, scrupulously, xxiii,
# Nearest to at: exerting, intruder, faunal, scenarios, peoria, trapezohedron, idolized, racehorse,
# Nearest to with: socialized, wickham, second, its, tgv, misunderstood, hor, meets,
# Nearest to may: shampoo, jurisdiction, suki, wahhabis, conduct, claim, belgian, partitioned,
# Nearest to four: five, two, one, three, zero, seven, eight, six,
# Nearest to shown: burkean, crystallography, dichromate, satisfiable, majesties, hailstones, ket, sefirot,
# Nearest to scale: matra, incurs, cracks, finalised, obj, jhana, and, landscapes,
# Nearest to engineering: disciplines, psychology, technology, robert, rfcs, healey, engineers, monopolies,
# Nearest to cost: shortages, enough, staff, economics, progesterone, decrypt, tradeoff, plans,
# Nearest to units: resumption, races, density, islander, arcseconds, pruitt, si, bundeswehr,
# Nearest to powers: deputies, politically, fdl, legislation, crematoria, advisers, parliamentary, kom,
# Nearest to except: written, is, regulus, schwa, tre, shear, refers, sprout,
# Nearest to mean: fossilized, entertains, digges, imparts, proportion, albertus, sterility, subsystem,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0043 0.1528 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0530 0.1566 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0653 0.1627 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0502 0.1493 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1384 0.1516 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0451 0.1548 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0441 0.1577 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9964 0.1508 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0563 0.1490 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0035 0.1497 sec/batch
# Nearest to state: kitty, missouri, lites, is, nebraska, heaps, immigrant, greetings,
# Nearest to had: was, so, accidentally, asherah, he, rumba, lacked, ruffians,
# Nearest to eight: five, one, two, nine, three, seven, four, six,
# Nearest to no: accountable, lopster, wait, religionists, waring, duly, xxiii, scrupulously,
# Nearest to at: faunal, exerting, peoria, intruder, trapezohedron, darjeeling, processions, idolized,
# Nearest to with: socialized, second, its, hor, wickham, panspermia, misunderstood, tgv,
# Nearest to may: shampoo, wahhabis, suki, belgian, adt, ah, conduct, tco,
# Nearest to four: five, one, two, three, seven, nine, zero, eight,
# Nearest to shown: burkean, crystallography, dichromate, pickles, contractile, sefirot, satisfiable, gizzard,
# Nearest to scale: matra, incurs, obj, cracks, landscapes, octave, finalised, notated,
# Nearest to engineering: disciplines, technology, monopolies, engineers, engineer, robert, borja, psychology,
# Nearest to cost: shortages, enough, economics, progesterone, staff, decrypt, tradeoff, chip,
# Nearest to units: resumption, races, density, islander, arcseconds, si, pruitt, counting,
# Nearest to powers: fdl, politically, advisers, talents, crematoria, deputies, legislation, quashed,
# Nearest to except: written, is, tre, schwa, regulus, refers, shear, realschule,
# Nearest to mean: fossilized, entertains, digges, albertus, imparts, proportion, latinate, abstracted,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0051 0.1513 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9684 0.1523 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0419 0.1481 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0587 0.1481 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0628 0.1489 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0089 0.1484 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9617 0.1482 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9825 0.1485 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9529 0.1475 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0181 0.1488 sec/batch
# Nearest to state: kitty, missouri, lites, nebraska, heaps, is, milloy, immigrant,
# Nearest to had: was, he, so, accidentally, ruffians, rumba, asherah, his,
# Nearest to eight: five, two, three, one, nine, seven, four, six,
# Nearest to no: accountable, lopster, wait, religionists, waring, torts, you, cosmides,
# Nearest to at: exerting, intruder, peoria, faunal, scenarios, cockpits, undertake, trapezohedron,
# Nearest to with: second, the, socialized, nonpolar, its, wickham, tgv, dissociate,
# Nearest to may: shampoo, belgian, wahhabis, owners, suki, conduct, adt, jurisdiction,
# Nearest to four: five, two, one, three, seven, zero, six, nine,
# Nearest to shown: burkean, crystallography, contractile, american, satisfiable, dichromate, warped, sefirot,
# Nearest to scale: matra, incurs, cracks, obj, jhana, finalised, landscapes, sampling,
# Nearest to engineering: disciplines, monopolies, psychology, courses, robert, technology, faculties, borja,
# Nearest to cost: enough, shortages, progesterone, tradeoff, economics, decrypt, staff, pins,
# Nearest to units: races, resumption, islander, density, si, pruitt, arcseconds, transporters,
# Nearest to powers: advisers, politically, kom, legislation, fdl, congreso, deputies, crematoria,
# Nearest to except: written, is, tre, regulus, refers, schwa, realschule, wolff,
# Nearest to mean: fossilized, entertains, digges, albertus, proportion, sterility, imparts, variation,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0254 0.1509 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0102 0.1482 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0432 0.1484 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0399 0.1481 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0519 0.1491 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9921 0.1492 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0383 0.1481 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0267 0.1487 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0132 0.1484 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0295 0.1475 sec/batch
# Nearest to state: kitty, is, heaps, milloy, lites, missouri, overseen, lii,
# Nearest to had: was, he, ruffians, robespierre, tried, dalit, so, lacked,
# Nearest to eight: five, one, nine, two, six, seven, three, four,
# Nearest to no: lopster, accountable, waring, xxiii, calculates, you, wait, fraenkel,
# Nearest to at: peoria, idolized, intruder, admission, insurer, scenarios, undertake, exerting,
# Nearest to with: second, dissociate, nonpolar, wickham, tgv, socialized, its, dentistry,
# Nearest to may: shampoo, conduct, owners, wahhabis, belgian, jurisdiction, suki, claim,
# Nearest to four: five, two, one, three, zero, seven, six, nine,
# Nearest to shown: burkean, crystallography, contractile, satisfiable, majesties, mev, warped, ket,
# Nearest to scale: matra, incurs, cracks, jhana, obj, sampling, maestro, landscapes,
# Nearest to engineering: disciplines, psychology, courses, engineers, technology, engineer, faculties, monopolies,
# Nearest to cost: enough, shortages, economics, tradeoff, staff, shortage, ac, decrypt,
# Nearest to units: races, resumption, islander, density, si, arcseconds, pruitt, counting,
# Nearest to powers: advisers, fdl, deputies, politically, congreso, legislation, kom, nation,
# Nearest to except: written, is, tre, regulus, schwa, realschule, refers, reprieve,
# Nearest to mean: fossilized, entertains, digges, albertus, variation, proportion, sterility, abstracted,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0219 0.1507 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9983 0.1495 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9971 0.1479 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0309 0.1489 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0398 0.1493 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0571 0.1487 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0091 0.1486 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9606 0.1494 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0240 0.1481 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0657 0.1500 sec/batch
# Nearest to state: is, kitty, missouri, lites, nebraska, overseen, heaps, rejected,
# Nearest to had: was, ruffians, dalit, it, robespierre, so, lacked, amanullah,
# Nearest to eight: five, one, two, nine, seven, three, six, four,
# Nearest to no: accountable, lopster, waring, you, wait, xxiii, calculates, not,
# Nearest to at: peoria, undertake, adar, faunal, exerting, idolized, agadir, gion,
# Nearest to with: second, the, wickham, socialized, its, hor, wien, panspermia,
# Nearest to may: shampoo, jurisdiction, conduct, owners, suki, belgian, voicing, wahhabis,
# Nearest to four: five, one, two, three, zero, seven, nine, six,
# Nearest to shown: burkean, majesties, satisfiable, ket, crystallography, anim, superhighway, beresford,
# Nearest to scale: matra, incurs, cracks, maestro, landscapes, sampling, obj, finalised,
# Nearest to engineering: disciplines, psychology, technology, engineers, courses, engineer, robert, faculties,
# Nearest to cost: enough, shortages, economics, tradeoff, shortage, ac, progesterone, pins,
# Nearest to units: races, resumption, islander, si, density, arcseconds, pruitt, bundeswehr,
# Nearest to powers: legislation, parliamentary, politically, advisers, fdl, deputies, crematoria, congreso,
# Nearest to except: is, written, tre, regulus, schwa, refers, chamada, reprieve,
# Nearest to mean: fossilized, variation, digges, proportion, entertains, albertus, imparts, latinate,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 4.0002 0.1512 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1159 0.1497 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.1035 0.1485 sec/batch
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8842 0.1493 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8899 0.1504 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8727 0.1486 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8977 0.1485 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.9102 0.1492 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9116 0.1495 sec/batch
# Nearest to state: nebraska, overseen, missouri, kitty, heaps, is, libertarians, platte,
# Nearest to had: was, he, were, later, so, though, did, tried,
# Nearest to eight: five, one, four, three, two, nine, six, seven,
# Nearest to no: duplicate, middle, constriction, ticket, when, waring, just, even,
# Nearest to at: from, in, to, the, first, a, august, commencement,
# Nearest to with: the, in, a, and, for, while, to, of,
# Nearest to may: observances, owners, as, belgian, birthday, olfactory, voicing, baa,
# Nearest to four: five, three, one, two, zero, eight, nine, six,
# Nearest to shown: classify, literals, unvoiced, dma, moreover, indicators, contractile, sefirot,
# Nearest to scale: matra, richter, tuning, octave, ten, tens, maestro, turkic,
# Nearest to engineering: engineers, engineer, disciplines, technology, psychology, geotechnical, courses, zanne,
# Nearest to cost: tradeoff, shortages, economics, benefits, chip, enough, sustain, clearly,
# Nearest to units: islander, joule, races, si, unit, density, inflict, makeup,
# Nearest to powers: paicv, fdl, talents, henares, constitutional, crematoria, reis, dubrovnik,
# Nearest to except: is, tre, regulus, given, last, written, sitter, item,
# Nearest to mean: variation, musset, tumble, proportion, entertains, better, digges, premium,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8520 0.1531 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8845 0.1489 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8906 0.1489 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8945 0.1495 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8677 0.1478 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8919 0.1492 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8871 0.1486 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8676 0.1489 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9034 0.1490 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9170 0.1491 sec/batch
# Nearest to state: overseen, is, nebraska, kitty, heaps, libertarians, bearers, missouri,
# Nearest to had: was, were, he, later, did, soon, tried, though,
# Nearest to eight: five, one, four, nine, three, two, seven, six,
# Nearest to no: duplicate, middle, info, radiocommunications, constriction, just, done, waring,
# Nearest to at: from, in, to, the, seamstress, first, commencement, apart,
# Nearest to with: the, in, a, of, and, while, by, second,
# Nearest to may: observances, belgian, owners, conduct, voicing, as, baa, martinique,
# Nearest to four: five, one, three, two, nine, zero, eight, seven,
# Nearest to shown: classify, literals, unvoiced, coronations, dma, sefirot, moreover, contractile,
# Nearest to scale: matra, richter, tuning, ten, tens, octave, observational, carver,
# Nearest to engineering: engineers, engineer, disciplines, technology, psychology, sadi, zanne, courses,
# Nearest to cost: tradeoff, shortages, economics, clearly, benefits, sustain, enough, chip,
# Nearest to units: islander, joule, si, races, unit, density, inflict, arcseconds,
# Nearest to powers: paicv, fdl, legislation, declare, constitutional, houses, talents, henares,
# Nearest to except: is, tre, regulus, given, last, written, sitter, cedes,
# Nearest to mean: variation, musset, tumble, proportion, digges, better, summing, linearity,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8744 0.1510 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8271 0.1490 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8508 0.1494 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8628 0.1487 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9512 0.1502 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8570 0.1493 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9611 0.1491 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9201 0.1494 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9201 0.1486 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8500 0.1481 sec/batch
# Nearest to state: nebraska, overseen, kitty, libertarians, is, missouri, heaps, secretaries,
# Nearest to had: was, were, he, later, did, to, tried, though,
# Nearest to eight: five, one, four, two, three, nine, seven, six,
# Nearest to no: duplicate, middle, info, kabyle, constriction, rest, radiocommunications, done,
# Nearest to at: from, in, the, to, first, august, on, seamstress,
# Nearest to with: the, in, a, and, while, for, by, of,
# Nearest to may: observances, belgian, owners, as, baa, martinique, birthday, voicing,
# Nearest to four: five, one, three, two, nine, zero, eight, seven,
# Nearest to shown: classify, literals, unvoiced, dma, moreover, coronations, newline, lewisham,
# Nearest to scale: richter, matra, tuning, ten, octave, tens, observational, carver,
# Nearest to engineering: engineers, engineer, disciplines, technology, psychology, zanne, sadi, robert,
# Nearest to cost: economics, shortages, tradeoff, benefits, sustain, clearly, enough, chip,
# Nearest to units: islander, joule, si, races, inflict, unit, density, cavalry,
# Nearest to powers: paicv, fdl, talents, legislation, constitutional, overseas, declare, crematoria,
# Nearest to except: is, tre, regulus, written, last, sitter, item, faroe,
# Nearest to mean: variation, musset, digges, tumble, premium, better, proportion, summing,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8574 0.1503 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8433 0.1488 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8235 0.1494 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8955 0.1498 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8443 0.1485 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.9187 0.1486 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9005 0.1121 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8714 0.1494 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8252 0.1492 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8909 0.1492 sec/batch
# Nearest to state: nebraska, is, greetings, overseen, kitty, libertarians, missouri, heaps,
# Nearest to had: was, were, he, later, did, though, to, so,
# Nearest to eight: five, one, nine, two, four, three, seven, six,
# Nearest to no: duplicate, middle, constriction, even, kabyle, rest, when, waring,
# Nearest to at: the, in, a, to, from, on, first, apart,
# Nearest to with: the, in, a, and, for, while, by, of,
# Nearest to may: observances, belgian, birthday, baa, shampoo, owners, martinique, as,
# Nearest to four: five, three, one, two, nine, zero, eight, six,
# Nearest to shown: literals, classify, unvoiced, dma, contractile, indicators, adrenal, moreover,
# Nearest to scale: tuning, richter, matra, octave, ten, scales, carver, tens,
# Nearest to engineering: engineers, engineer, disciplines, technology, psychology, sadi, zanne, geotechnical,
# Nearest to cost: tradeoff, shortages, economics, clearly, sustain, benefits, chip, enough,
# Nearest to units: islander, joule, si, inflict, unit, density, races, arcseconds,
# Nearest to powers: paicv, fdl, talents, legislation, shamans, constitutional, overseas, declare,
# Nearest to except: is, tre, regulus, sitter, given, cedes, written, absolutive,
# Nearest to mean: variation, musset, tumble, premium, digges, kendal, telescoping, proportion,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8178 0.1514 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8612 0.1490 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7882 0.1488 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8848 0.1484 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8755 0.1485 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8776 0.1483 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8671 0.1485 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7799 0.1485 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8423 0.1486 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7976 0.1493 sec/batch
# Nearest to state: overseen, libertarians, nebraska, greetings, missouri, capital, kitty, bearers,
# Nearest to had: was, were, he, later, did, though, soon, tried,
# Nearest to eight: five, one, two, three, four, nine, seven, six,
# Nearest to no: duplicate, middle, even, constriction, when, ticket, info, calculates,
# Nearest to at: in, from, to, the, first, a, on, apart,
# Nearest to with: the, in, a, and, for, of, to, by,
# Nearest to may: observances, as, belgian, birthday, owners, shampoo, baa, martinique,
# Nearest to four: five, three, one, two, nine, zero, eight, six,
# Nearest to shown: classify, unvoiced, literals, contractile, moreover, adrenal, dma, indicators,
# Nearest to scale: tuning, matra, richter, octave, ten, observational, tens, carver,
# Nearest to engineering: engineers, engineer, disciplines, technology, psychology, courses, sadi, geotechnical,
# Nearest to cost: shortages, tradeoff, economics, clearly, sustain, enough, chip, benefits,
# Nearest to units: islander, joule, si, unit, density, races, inflict, prefixes,
# Nearest to powers: paicv, fdl, shamans, legislation, constitutional, talents, henares, crematoria,
# Nearest to except: is, tre, last, regulus, sitter, given, and, written,
# Nearest to mean: variation, musset, better, tumble, proportion, premium, telescoping, digges,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8303 0.1512 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8539 0.1484 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8738 0.1486 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8182 0.1486 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8581 0.1481 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9489 0.1485 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8065 0.1486 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8620 0.1485 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8785 0.1487 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8579 0.1492 sec/batch
# Nearest to state: is, overseen, kitty, libertarians, bearers, nebraska, greetings, heaps,
# Nearest to had: was, were, he, later, did, tried, soon, it,
# Nearest to eight: five, one, nine, four, two, three, six, seven,
# Nearest to no: middle, duplicate, constriction, when, shorter, rest, even, kabyle,
# Nearest to at: in, first, from, the, a, to, four, that,
# Nearest to with: the, a, in, for, by, and, while, of,
# Nearest to may: as, owners, observances, birthday, belgian, by, to, on,
# Nearest to four: five, one, three, two, nine, zero, eight, six,
# Nearest to shown: classify, unvoiced, literals, coronations, contractile, moreover, adrenal, ctrl,
# Nearest to scale: richter, tuning, matra, octave, ten, carver, observational, tens,
# Nearest to engineering: engineers, engineer, disciplines, technology, psychology, courses, sadi, geotechnical,
# Nearest to cost: shortages, economics, tradeoff, clearly, sustain, chip, enough, costs,
# Nearest to units: islander, joule, si, unit, density, races, makeup, inflict,
# Nearest to powers: paicv, fdl, legislation, constitutional, talents, nation, congreso, shamans,
# Nearest to except: is, given, tre, written, last, regulus, only, both,
# Nearest to mean: musset, variation, better, premium, digges, tumble, proportion, kendal,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8568 0.1506 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8913 0.1485 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8579 0.1491 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8662 0.1485 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8884 0.1489 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8532 0.1487 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8618 0.1492 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8762 0.1485 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8153 0.1492 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8110 0.1482 sec/batch
# Nearest to state: overseen, is, kitty, nebraska, libertarians, bearers, heaps, greetings,
# Nearest to had: was, were, later, he, did, soon, tried, made,
# Nearest to eight: five, one, two, three, four, nine, six, seven,
# Nearest to no: duplicate, info, middle, constriction, done, jargon, even, when,
# Nearest to at: in, from, first, the, to, a, that, apart,
# Nearest to with: the, a, in, by, of, while, and, for,
# Nearest to may: as, to, conduct, owners, by, for, observances, the,
# Nearest to four: five, one, three, two, zero, nine, eight, seven,
# Nearest to shown: classify, unvoiced, literals, coronations, moreover, dma, leppard, adrenal,
# Nearest to scale: richter, tuning, matra, octave, ten, carver, tens, observational,
# Nearest to engineering: engineers, engineer, technology, disciplines, psychology, geotechnical, sadi, courses,
# Nearest to cost: shortages, economics, tradeoff, sustain, enough, benefits, chip, silicon,
# Nearest to units: islander, joule, si, unit, density, races, inflict, makeup,
# Nearest to powers: paicv, fdl, legislation, declare, shamans, constitutional, nation, parliamentary,
# Nearest to except: is, tre, written, last, regulus, and, given, absolutive,
# Nearest to mean: variation, musset, tumble, premium, better, telescoping, summing, proportion,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.9042 0.1518 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8342 0.1505 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9820 0.1498 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8929 0.1482 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9238 0.1479 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8258 0.1490 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7895 0.1477 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8809 0.1484 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.8046 0.1485 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8915 0.1491 sec/batch
# Nearest to state: overseen, nebraska, greetings, bearers, kitty, is, platte, libertarians,
# Nearest to had: was, later, he, were, did, soon, could, tried,
# Nearest to eight: one, five, two, nine, four, three, seven, six,
# Nearest to no: duplicate, middle, info, constriction, when, start, shorter, consequences,
# Nearest to at: in, from, the, first, on, a, close, to,
# Nearest to with: the, a, in, for, by, while, and, of,
# Nearest to may: birthday, observances, as, belgian, owners, martinique, on, baa,
# Nearest to four: one, three, five, two, nine, zero, eight, seven,
# Nearest to shown: literals, classify, coronations, unvoiced, moreover, indicators, leppard, philippians,
# Nearest to scale: richter, tuning, matra, octave, carver, ten, tens, scales,
# Nearest to engineering: engineers, engineer, disciplines, technology, psychology, sadi, geotechnical, zanne,
# Nearest to cost: economics, clearly, shortages, tradeoff, costs, benefits, sustain, expected,
# Nearest to units: islander, si, joule, unit, density, makeup, races, prefixes,
# Nearest to powers: paicv, fdl, legislation, shamans, steel, talents, constitutional, declare,
# Nearest to except: is, tre, written, regulus, sitter, demarcating, given, reprieve,
# Nearest to mean: variation, musset, tumble, linearity, digges, better, summing, telescoping,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8675 0.1510 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8478 0.1495 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
